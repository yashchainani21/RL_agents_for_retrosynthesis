# %%
import pickle
from rdkit import Chem
from rdkit.Chem import AllChem

# %%
with open('../data/evaluation/routes_possible_test_hard.pkl', 'rb') as f:
    data = pickle.load(f)

# %%
for rxn_str in data[0]:
    rxn = AllChem.ReactionFromSmarts(rxn_str)

# %%
data[3]
# Out:
# ['CCOC(=O)c1nc(N2CC[C@H](NC(=O)c3nc(C(F)(F)F)c(CC)[nH]3)[C@H](OC)C2)sc1C>>CCOC(=O)c1nc(N2CC[C@H](N)[C@H](OC)C2)sc1C.CCc1[nH]c(C(=O)O)nc1C(F)(F)F',
#  'CCOC(=O)c1nc(N2CC[C@H](N)[C@H](OC)C2)sc1C>>CCOC(=O)c1nc(N2CC[C@H](NC(=O)OCc3ccccc3)[C@H](OC)C2)sc1C',
#  'CCc1[nH]c(C(=O)O)nc1C(F)(F)F>>[O-][Cl+][O-].CCc1[nH]c(C=O)nc1C(F)(F)F',
#  'CCOC(=O)c1nc(N2CC[C@H](NC(=O)OCc3ccccc3)[C@H](OC)C2)sc1C>>CO[C@@H]1CNCC[C@@H]1NC(=O)OCc1ccccc1.CCOC(=O)c1nc(Br)sc1C',
#  'CO[C@@H]1CNCC[C@@H]1NC(=O)OCc1ccccc1>>CO[C@@H]1CN(C(=O)OC(C)(C)C)CC[C@@H]1NC(=O)OCc1ccccc1',
#  'CO[C@@H]1CN(C(=O)OC(C)(C)C)CC[C@@H]1NC(=O)OCc1ccccc1>>CO[C@@H]1CN(C(=O)OC(C)(C)C)CC[C@@H]1N.O=C(Cl)OCc1ccccc1',
#  'CCc1[nH]c(C=O)nc1C(F)(F)F>>CCc1[nH]c(C(OC)OC)nc1C(F)(F)F',
#  'CCc1[nH]c(C(OC)OC)nc1C(F)(F)F>>CCC1(C(=O)C(F)(F)F)SCCCS1.O=C1CCC(=O)N1Cl.N.COC(C=O)OC',
#  'CCC1(C(=O)C(F)(F)F)SCCCS1>>CCC1SCCCS1.CCOC(=O)C(F)(F)F']
